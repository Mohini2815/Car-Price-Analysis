# %% [markdown]
# # Second hand car price project

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("C:\\Users\\mohin\\Downloads\\cars.csv")

# %%
df
# Out:
#     Car_ID     Brand          Model  Year  Kilometers_Driven Fuel_Type  \
# 0        1    Toyota        Corolla  2018              50000    Petrol
# 1        2     Honda          Civic  2019              40000    Petrol
# 2        3      Ford        Mustang  2017              20000    Petrol
# 3        4    Maruti          Swift  2020              30000    Diesel
# 4        5   Hyundai         Sonata  2016              60000    Diesel
# ..     ...       ...            ...   ...                ...       ...
# 95      96  Mercedes        C-Class  2019              22000    Diesel
# 96      97    Toyota  Innova Crysta  2017              38000    Diesel
# 97      98      Ford       EcoSport  2018              26000    Petrol
# 98      99   Hyundai          Verna  2019              24000    Petrol
# 99     100      Tata         Altroz  2020              18000    Petrol
#
#    Transmission Owner_Type  Mileage  Engine  Power  Seats    Price
# 0        Manual      First       15    1498    108      5   800000
# 1     Automatic     Second       17    1597    140      5  1000000
# 2     Automatic      First       10    4951    395      4  2500000
# 3        Manual      Third       23    1248     74      5   600000
# 4     Automatic     Second       18    1999    194      5   850000
# ..          ...        ...      ...     ...    ...    ...      ...
# 95    Automatic      First       16    1950    191      5  2900000
# 96       Manual     Second       13    2755    171      7  1400000
# 97       Manual      Third       18    1497    121      5   750000
# 98    Automatic     Second       17    1497    113      5   850000
# 99       Manual      First       20    1199     85      5   600000
#
# [100 rows x 13 columns]

# %%
df.head()
# Out:
#    Car_ID    Brand    Model  Year  Kilometers_Driven Fuel_Type Transmission  \
# 0       1   Toyota  Corolla  2018              50000    Petrol       Manual
# 1       2    Honda    Civic  2019              40000    Petrol    Automatic
# 2       3     Ford  Mustang  2017              20000    Petrol    Automatic
# 3       4   Maruti    Swift  2020              30000    Diesel       Manual
# 4       5  Hyundai   Sonata  2016              60000    Diesel    Automatic
#
#   Owner_Type  Mileage  Engine  Power  Seats    Price
# 0      First       15    1498    108      5   800000
# 1     Second       17    1597    140      5  1000000
# 2      First       10    4951    395      4  2500000
# 3      Third       23    1248     74      5   600000
# 4     Second       18    1999    194      5   850000

# %%
df.tail()
# Out:
#     Car_ID     Brand          Model  Year  Kilometers_Driven Fuel_Type  \
# 95      96  Mercedes        C-Class  2019              22000    Diesel
# 96      97    Toyota  Innova Crysta  2017              38000    Diesel
# 97      98      Ford       EcoSport  2018              26000    Petrol
# 98      99   Hyundai          Verna  2019              24000    Petrol
# 99     100      Tata         Altroz  2020              18000    Petrol
#
#    Transmission Owner_Type  Mileage  Engine  Power  Seats    Price
# 95    Automatic      First       16    1950    191      5  2900000
# 96       Manual     Second       13    2755    171      7  1400000
# 97       Manual      Third       18    1497    121      5   750000
# 98    Automatic     Second       17    1497    113      5   850000
# 99       Manual      First       20    1199     85      5   600000

# %%
df.describe(include='all')
# Out:
#             Car_ID Brand    Model        Year  Kilometers_Driven Fuel_Type  \
# count   100.000000   100      100   100.00000         100.000000       100
# unique         NaN    11       58         NaN                NaN         2
# top            NaN  Ford  Mustang         NaN                NaN    Petrol
# freq           NaN    11        3         NaN                NaN        52
# mean     50.500000   NaN      NaN  2018.39000       28150.000000       NaN
# std      29.011492   NaN      NaN     1.17116        9121.375716       NaN
# min       1.000000   NaN      NaN  2016.00000       10000.000000       NaN
# 25%      25.750000   NaN      NaN  2017.75000       22000.000000       NaN
# 50%      50.500000   NaN      NaN  2018.00000       27000.000000       NaN
# 75%      75.250000   NaN      NaN  2019.00000       32000.000000       NaN
# max     100.000000   NaN      NaN  2021.00000       60000.000000       NaN
#
#        Transmission Owner_Type     Mileage       Engine       Power  \
# count           100        100  100.000000   100.000000  100.000000
# unique            2          3         NaN          NaN         NaN
# top       Automatic      First         NaN          NaN         NaN
# freq             57         44         NaN          NaN         NaN
# mean            NaN        NaN   17.210000  1855.230000  158.130000
# std             NaN        NaN    3.309902   631.311475   76.968137
# min             NaN        NaN   10.000000   999.000000   68.000000
# 25%             NaN        NaN   15.000000  1462.000000  103.000000
# 50%             NaN        NaN   17.000000  1774.000000  148.000000
# 75%             NaN        NaN   19.000000  2143.000000  187.000000
# max             NaN        NaN   25.000000  4951.000000  396.000000
#
#              Seats         Price
# count   100.000000  1.000000e+02
# unique         NaN           NaN
# top            NaN           NaN
# freq           NaN           NaN
# mean      5.230000  1.574000e+06
# std       0.750151  1.000265e+06
# min       4.000000  4.500000e+05
# 25%       5.000000  7.000000e+05
# 50%       5.000000  1.300000e+06
# 75%       5.000000  2.500000e+06
# max       7.000000  4.000000e+06

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Car_ID             100 non-null    int64
#  1   Brand              100 non-null    object
#  2   Model              100 non-null    object
#  3   Year               100 non-null    int64
#  4   Kilometers_Driven  100 non-null    int64
#  5   Fuel_Type          100 non-null    object
#  6   Transmission       100 non-null    object
#  7   Owner_Type         100 non-null    object
#  8   Mileage            100 non-null    int64
#  9   Engine             100 non-null    int64
#  10  Power              100 non-null    int64
#  11  Seats              100 non-null    int64
#  12  Price              100 non-null    int64
# dtypes: int64(8), object(5)
# memory usage: 10.3+ KB

# %%
df.nunique()
# Out:
# Car_ID               100
# Brand                 11
# Model                 58
# Year                   6
# Kilometers_Driven     18
# Fuel_Type              2
# Transmission           2
# Owner_Type             3
# Mileage               15
# Engine                36
# Power                 40
# Seats                  3
# Price                 31
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Car_ID               0
# Brand                0
# Model                0
# Year                 0
# Kilometers_Driven    0
# Fuel_Type            0
# Transmission         0
# Owner_Type           0
# Mileage              0
# Engine               0
# Power                0
# Seats                0
# Price                0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# - The dataset contains 5 object columns and 8 numerical columns.
# - The dataset does not contain any null values also duplicate values.

# %% [markdown]
# **Non graphical visualizations**

# %% [markdown]
# - There are 11 car brands present in dataset.
# - There are 2 fuel types present in the dataset.

# %%
df['Brand'].unique()
# Out:
# array(['Toyota', 'Honda', 'Ford', 'Maruti', 'Hyundai', 'Tata', 'Mahindra',
#        'Volkswagen', 'Audi', 'BMW', 'Mercedes'], dtype=object)

# %%
df['Fuel_Type'].unique()
# Out:
# array(['Petrol', 'Diesel'], dtype=object)

# %%
df['Brand'].value_counts()
# Out:
# Brand
# Ford          11
# Hyundai       11
# Tata          11
# Toyota        10
# Volkswagen    10
# Audi          10
# BMW           10
# Mercedes      10
# Honda          6
# Maruti         6
# Mahindra       5
# Name: count, dtype: int64

# %%
df['Seats'].unique()
# Out:
# array([5, 4, 7], dtype=int64)

# %%
df['Fuel_Type'].value_counts()
# Out:
# Fuel_Type
# Petrol    52
# Diesel    48
# Name: count, dtype: int64

# %%
df[df['Fuel_Type']=='Petrol'].head(20)
# Out:
#     Car_ID       Brand    Model  Year  Kilometers_Driven Fuel_Type  \
# 0        1      Toyota  Corolla  2018              50000    Petrol
# 1        2       Honda    Civic  2019              40000    Petrol
# 2        3        Ford  Mustang  2017              20000    Petrol
# 5        6        Tata    Nexon  2019              35000    Petrol
# 7        8  Volkswagen     Polo  2020              25000    Petrol
# 10      11    Mercedes  C-Class  2018              28000    Petrol
# 12      13     Hyundai    Creta  2019              22000    Petrol
# 14      15      Maruti   Ertiga  2020              18000    Petrol
# 17      18        Audi       Q3  2016              38000    Petrol
# 19      20    Mercedes      GLC  2017              26000    Petrol
# 21      22        Ford     Figo  2020              15000    Petrol
# 23      24        Tata   Altroz  2020              18000    Petrol
# 26      27        Audi       A6  2018              28000    Petrol
# 30      31        Ford   Aspire  2019              26000    Petrol
# 33      34      Maruti   Vitara  2019              24000    Petrol
# 35      36  Volkswagen     Ameo  2020              15000    Petrol
# 36      37        Audi       A3  2017              38000    Petrol
# 38      39    Mercedes      GLE  2018              26000    Petrol
# 39      40      Toyota    Yaris  2020              18000    Petrol
# 41      42     Hyundai   Santro  2019              26000    Petrol
#
#    Transmission Owner_Type  Mileage  Engine  Power  Seats    Price
# 0        Manual      First       15    1498    108      5   800000
# 1     Automatic     Second       17    1597    140      5  1000000
# 2     Automatic      First       10    4951    395      4  2500000
# 5        Manual      First       17    1198    108      5   750000
# 7     Automatic      First       18     999     76      5   650000
# 10    Automatic      First       16    1991    181      5  2300000
# 12       Manual      Third       16    1497    113      5   850000
# 14       Manual      First       19    1462    103      7   850000
# 17    Automatic     Second       15    1395    148      5  1900000
# 19    Automatic     Second       12    1991    241      5  2500000
# 21       Manual      Third       18    1194     94      5   550000
# 23       Manual      First       20    1199     85      5   600000
# 26    Automatic      First       15    1984    241      5  3200000
# 30       Manual      Third       20    1194     94      5   600000
# 33       Manual     Second       17    1462    103      5   700000
# 35    Automatic      Third       19    1197     74      5   500000
# 36    Automatic     Second       16    1395    148      5  2000000
# 38    Automatic     Second       12    2996    362      5  4000000
# 39       Manual      First       17    1496    106      5   650000
# 41       Manual      Third       20    1086     68      5   450000

# %%
df[df['Fuel_Type']=='Diesel'].head(20)
# Out:
#     Car_ID       Brand      Model  Year  Kilometers_Driven Fuel_Type  \
# 3        4      Maruti      Swift  2020              30000    Diesel
# 4        5     Hyundai     Sonata  2016              60000    Diesel
# 6        7    Mahindra    Scorpio  2018              45000    Diesel
# 8        9        Audi         A4  2017              30000    Diesel
# 9       10         BMW         X1  2019              20000    Diesel
# 11      12        Ford  Endeavour  2017              35000    Diesel
# 13      14        Tata    Harrier  2018              40000    Diesel
# 15      16       Honda       City  2017              42000    Diesel
# 16      17  Volkswagen     Tiguan  2018              32000    Diesel
# 18      19         BMW   5 Series  2019              24000    Diesel
# 20      21      Toyota     Innova  2018              50000    Diesel
# 22      23     Hyundai      Verna  2019              26000    Diesel
# 24      25    Mahindra       Thar  2021              10000    Diesel
# 25      26  Volkswagen     Passat  2017              32000    Diesel
# 27      28         BMW         X3  2019              22000    Diesel
# 28      29    Mercedes    E-Class  2017              30000    Diesel
# 29      30      Toyota   Fortuner  2018              38000    Diesel
# 31      32     Hyundai    Elantra  2017              32000    Diesel
# 32      33        Tata     Safari  2018              42000    Diesel
# 34      35       Honda       WR-V  2018              28000    Diesel
#
#    Transmission Owner_Type  Mileage  Engine  Power  Seats    Price
# 3        Manual      Third       23    1248     74      5   600000
# 4     Automatic     Second       18    1999    194      5   850000
# 6     Automatic     Second       15    2179    140      7   900000
# 8     Automatic      First       18    1968    187      5  2200000
# 9     Automatic     Second       20    1995    190      5  2700000
# 11    Automatic     Second       12    2198    158      7  2000000
# 13    Automatic      First       17    1956    167      5  1600000
# 15       Manual     Second       25    1498     98      5   650000
# 16    Automatic      First       17    1968    141      5  1800000
# 18    Automatic      First       18    1995    187      5  3000000
# 20       Manual      First       13    2755    171      7  1400000
# 22    Automatic     Second       24    1582    126      5   850000
# 24       Manual      First       15    2184    130      4  1200000
# 25    Automatic     Second       17    1968    174      5  1600000
# 27    Automatic     Second       18    1995    187      5  2800000
# 28    Automatic      First       16    1950    191      5  2700000
# 29    Automatic     Second       12    2755    174      7  2500000
# 31    Automatic     Second       22    1582    126      5   800000
# 32       Manual      First       14    1956    150      7  1300000
# 34       Manual      First       25    1498     98      5   750000

# %% [markdown]
# **Graphical Visualizations**

# %%
plt.figure(figsize=(12,5))
ax=sns.histplot(df['Brand'],bins=20,color='purple',kde=True)
for bars in ax.containers:
    ax.bar_label(bars)
plt.title('Brand Distribution')
plt.xlabel('Brand')
plt.ylabel('Distributions')
plt.show()

# %% [markdown]
# **Brand distribution**
# - Distribution is fairly distributed.
# - The brand Ford, Hyundai and Tata are shows the highest distribution.
# - The brand Toyota, volkswagen,Audi, BMW, Merecedes shows the little bit lowest distribution than above 3 brands.

# %%
plt.figure(figsize=(8,5))
ax=sns.countplot(x=df['Fuel_Type'],palette='Set2')
for bars in ax.containers:
    ax.bar_label(bars)
plt.title('Fuel Distribution')
plt.xlabel('Fuel')
plt.ylabel('Distributions')
plt.show()
# Out:
# C:\Users\mohin\AppData\Local\Temp\ipykernel_19464\1774726219.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax=sns.countplot(x=df['Fuel_Type'],palette='Set2')

# %% [markdown]
# **Fuel type distribution**
# - The chart shows that Petrol is the most common fuel type among the cars. i.e. its count is 52.

# %%
plt.figure(figsize=(8,4))
ax=sns.countplot(x=df['Transmission'],palette='Set2')
for bars in ax.containers:
    ax.bar_label(bars)
plt.title('Transmission Distribution')
plt.xlabel('Transmission')
plt.ylabel('Distribution')
plt.show()
# Out:
# C:\Users\mohin\AppData\Local\Temp\ipykernel_19464\3661091746.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax=sns.countplot(x=df['Transmission'],palette='Set2')

# %% [markdown]
# **Transmission Distribution**
# - With highest count(57) the chart indicates that Automatic transmission are more prevalent in the dataset.

# %%
plt.figure(figsize=(8,4))
ax=sns.countplot(x=df['Year'],palette='Set2')
for bars in ax.containers:
    ax.bar_label(bars)
plt.title('Year Distribution')
plt.xlabel('Year')
plt.ylabel('Distribution')
plt.show()
# Out:
# C:\Users\mohin\AppData\Local\Temp\ipykernel_19464\2675634852.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax=sns.countplot(x=df['Year'],palette='Set2')

# %% [markdown]
# **Year Distribution**
# - Distribution is not linearly spread.
# - Years 2018 and 2019 show the highest number of distributions with 28 cars each.
# - Years 2016 and 2021 show the lowest number of distributions with 4 and 2 cars.

# %%
plt.figure(figsize=(8,5))
ax=sns.countplot(x=df['Owner_Type'],palette='Set2')
for bars in ax.containers:
    ax.bar_label(bars)
plt.title('Owner Distribution')
plt.xlabel('Owner')
plt.ylabel('Distributions')
plt.show()
# Out:
# C:\Users\mohin\AppData\Local\Temp\ipykernel_19464\2185007189.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax=sns.countplot(x=df['Owner_Type'],palette='Set2')

# %% [markdown]
# **Owner Type distribution**
# - The counts of first and second owners are quite close.

# %%
plt.figure(figsize=(12,5))
ax=sns.histplot(df['Price'],bins=20,color='purple',kde=True)
for bars in ax.containers:
    ax.bar_label(bars)
plt.title('Price Distribution')
plt.xlabel('Price')
plt.ylabel('Distributions')
plt.show()

# %% [markdown]
# **Price Distributions**
# - The distribution appears to be positively skewed or right skewed.
# - There are more cars at the lower price ranges.

# %%
plt.figure(figsize=(8,5))
ax=sns.countplot(x=df['Seats'],palette='Set2')
for bars in ax.containers:
    ax.bar_label(bars)
plt.title('Seats Distribution')
plt.xlabel('Seats')
plt.ylabel('Distributions')
plt.show()
# Out:
# C:\Users\mohin\AppData\Local\Temp\ipykernel_19464\1497379651.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax=sns.countplot(x=df['Seats'],palette='Set2')

# %% [markdown]
# **Seats distribution**
# - The 5-seater cars are overwhelmingly dominant with count of 81.

# %%
df['Power'].unique()
# Out:
# array([108, 140, 395,  74, 194,  76, 187, 190, 181, 158, 113, 167, 103,
#         98, 141, 148, 241, 171,  94, 126,  85, 130, 174, 191, 150, 261,
#        362, 106,  68,  69, 245, 335, 170, 176, 396,  81,  84, 115, 258,
#        121], dtype=int64)

# %%
plt.figure(figsize=(12,5))
ax=sns.histplot(df['Power'],bins=20,color='purple',kde=True)
for bars in ax.containers:
    ax.bar_label(bars)
plt.title('Power Distribution')
plt.xlabel('Power')
plt.ylabel('Distributions')
plt.show()

# %% [markdown]
# **Power distribution**
# - The area between the two peaks (around 100-150)has a relatively low frequency of cars.

# %%
plt.figure(figsize=(12,5))
ax=sns.histplot(df['Kilometers_Driven'],bins=20,color='purple',kde=True)
for bars in ax.containers:
    ax.bar_label(bars)
plt.title('Kilometers Driven Distribution')
plt.xlabel('Kilometers Driven')
plt.ylabel('Distributions')
plt.show()

# %% [markdown]
# **Kilometers driven**
# - The highest number of cars falls within the 20,000 to 30,000 kilometer range.
# - There are a couple of gaps in the histogram specifically at 50000 and 60000 kilometers.

# %%
num=['Brand','Year','Kilometers_Driven','Fuel_Type','Transmission','Owner_Type','Mileage','Engine','Power','Seats','Price']
def univariate_analysis(n):
    plt.figure(figsize=(20, 24))
    for i, col in enumerate(n, 1):
        plt.subplot(6,2,i)
        plt.title(f"Count of {col}")
        sns.histplot(x=df[col],bins=20,color='purple',kde=True)
    plt.show()

univariate_analysis(num)

# %%
num=['Year','Kilometers_Driven','Engine','Power','Seats']
def univariate_analysis(n):
    plt.figure(figsize=(20, 24))
    for i, col in enumerate(n, 1):
        plt.subplot(4,2,i)
        plt.title(f"Count of {col}")
        sns.boxplot(x=df[col])
    plt.show()

univariate_analysis(num)

# %% [markdown]
# **Boxplot**
# - Above distribution shows that the only few columns from dataset have few numbers of outliers.

# %%
plt.figure(figsize=(12,5))
ax=sns.countplot(data=df, x='Brand',hue='Fuel_Type',palette='coolwarm')
for bars in ax.containers:
    ax.bar_label(bars)
plt.title('Brand vs Fuel type')
plt.xlabel('Brand')
plt.ylabel('Fuel type')
plt.show()

# %%
# made new feature for indicating car age
df['Car_Age'] = 2025 - df['Year']

# %%
df['Car_Age']
# Out:
# 0     7
# 1     6
# 2     8
# 3     5
# 4     9
#      ..
# 95    6
# 96    8
# 97    7
# 98    6
# 99    5
# Name: Car_Age, Length: 100, dtype: int64

# %%
# dropping unusable columns
# Car_Id ,Year and Seats
#df = df.drop(columns=['Car_ID'])

# %%
df = df.drop(columns=['Year'])

# %%
df = df.drop(columns=['Seats'])

# %%
df
# Out:
#     Car_ID     Brand          Model  Kilometers_Driven Fuel_Type Transmission  \
# 0        1    Toyota        Corolla              50000    Petrol       Manual
# 1        2     Honda          Civic              40000    Petrol    Automatic
# 2        3      Ford        Mustang              20000    Petrol    Automatic
# 3        4    Maruti          Swift              30000    Diesel       Manual
# 4        5   Hyundai         Sonata              60000    Diesel    Automatic
# ..     ...       ...            ...                ...       ...          ...
# 95      96  Mercedes        C-Class              22000    Diesel    Automatic
# 96      97    Toyota  Innova Crysta              38000    Diesel       Manual
# 97      98      Ford       EcoSport              26000    Petrol       Manual
# 98      99   Hyundai          Verna              24000    Petrol    Automatic
# 99     100      Tata         Altroz              18000    Petrol       Manual
#
#    Owner_Type  Mileage  Engine  Power    Price  Car_Age
# 0       First       15    1498    108   800000        7
# 1      Second       17    1597    140  1000000        6
# 2       First       10    4951    395  2500000        8
# 3       Third       23    1248     74   600000        5
# 4      Second       18    1999    194   850000        9
# ..        ...      ...     ...    ...      ...      ...
# 95      First       16    1950    191  2900000        6
# 96     Second       13    2755    171  1400000        8
# 97      Third       18    1497    121   750000        7
# 98     Second       17    1497    113   850000        6
# 99      First       20    1199     85   600000        5
#
# [100 rows x 12 columns]

# %% [markdown]
# **Heatmap**

# %% [markdown]
# **LabelEncoding**

# %%
 from sklearn.preprocessing import LabelEncoder
categorical_columns =["Brand", "Model", "Fuel_Type", "Transmission", "Owner_Type"] 

le= LabelEncoder()


for col in categorical_columns:
    df[col] = le.fit_transform(df[col])

# %%
corr_matrix = df.corr()

plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.title("Correlation Heatmap") 
plt.show()

# %% [markdown]
# **Kurtosis**

# %%
from scipy.stats import skew, kurtosis
# apply kurtosis on numerical columns
num_col = df.select_dtypes(include=['int64','float64']).columns
skewness = df[num_col].apply(skew).rename("Skewness")
value = df[num_col].apply(kurtosis).rename("Kurtosis")
metrics = pd.concat([skewness,value],axis=1)

# %%
metrics
# Out:
#                    Skewness  Kurtosis
# Car_ID             0.000000 -1.200240
# Kilometers_Driven  0.611903  0.592353
# Mileage            0.366971 -0.108923
# Engine             1.529325  4.324270
# Power              1.411690  1.814775
# Price              0.605033 -0.953856
# Car_Age           -0.001225 -0.719703

# %% [markdown]
# **Skewness**
# - In numerical features (Kilometers_Driven,Mileage	,Engine,Power,Price) all features have slightly and strongly skewed.
#
# **Kurtosis**
# - Among all numerical features, feature Engine is Leptokurtic which shows highly tailedness(4.32>3).

# %% [markdown]
# **ANNOVA**
# - Will apply on categorical features(Brand,fuel type,transmission and owner type).

# %%
from scipy.stats import f_oneway 
cat_features = ['Brand', 'Fuel_Type', 'Transmission', 'Owner_Type']

for feature in cat_features:
    groups = [df[df[feature] == category]['Price'] for category in df[feature].unique()]
    f_stat, p_value = f_oneway(*groups) #unpacks the list of groups into separate arguments for the function.
    
    print(f"ANOVA results for {feature}:")
    print(f" F-statistic: {f_stat:.2f}")
    print(f" P-value: {p_value:.4f}\n")
# Out:
# ANOVA results for Brand:
#  F-statistic: 28.23
#  P-value: 0.0000
#
# ANOVA results for Fuel_Type:
#  F-statistic: 3.32
#  P-value: 0.0716
#
# ANOVA results for Transmission:
#  F-statistic: 82.69
#  P-value: 0.0000
#
# ANOVA results for Owner_Type:
#  F-statistic: 8.31
#  P-value: 0.0005

# %% [markdown]
# **Brand**
# - f-statistic = 28.23
# - p-value = 0.0000(p-value is less than 0.05).
#
# **Fuel_Type**
# - f-statistic = 3.32
# - p-value = 0.0716(p-value is greater than 0.05).
#
# **Transmission**
# - f-statistic = 82.69
# - p-value = 0.0000(p-value is less than 0.05).
#
# **Owner_Type**
# - f-statistic = 8.31
# - p-value = 0.0000(p-value is less than 0.05).

# %% [markdown]
# **Models**

# %%
x = df.drop(columns=['Price'])
y = df['Price']

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report,accuracy_score


rf=RandomForestClassifier(random_state=42)#n_estimators=100
rf.fit(x_train,y_train)

y_pred=rf.predict(x_test)

accuracy = accuracy_score(y_test,y_pred)
print("Accuracy:",accuracy)

class_report = classification_report(y_test,y_pred)
print("Classification Report:",class_report)
# Out:
# Accuracy: 0.55
# Classification Report:               precision    recall  f1-score   support
#
#       500000       1.00      1.00      1.00         3
#       600000       1.00      1.00      1.00         1
#       650000       0.00      0.00      0.00         2
#       700000       0.50      1.00      0.67         2
#       750000       0.00      0.00      0.00         0
#       800000       0.50      0.50      0.50         2
#       850000       0.50      0.50      0.50         4
#      1300000       1.00      1.00      1.00         1
#      1600000       0.00      0.00      0.00         2
#      2300000       0.00      0.00      0.00         1
#      2700000       0.00      0.00      0.00         0
#      2800000       0.00      0.00      0.00         0
#      3000000       0.00      0.00      0.00         1
#      4000000       1.00      1.00      1.00         1
#
#     accuracy                           0.55        20
#    macro avg       0.39      0.43      0.40        20
# weighted avg       0.50      0.55      0.52        20
# C:\Users\mohin\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\mohin\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\mohin\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\mohin\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\mohin\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\mohin\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import accuracy_score,classification_report

gbc_classifier=GradientBoostingClassifier(n_estimators=100,random_state=42)

gbc_classifier.fit(x_train,y_train)

y_pred=gbc_classifier.predict(x_test)

accuracy=accuracy_score(y_test,y_pred)
print("Accuracy",accuracy)

class_report=classification_report(y_test,y_pred)
print("Gradient boosting classifier's classification report\n:",class_report)
# Out:
# Accuracy 0.5
# Gradient boosting classifier's classification report
# :               precision    recall  f1-score   support
#
#       500000       1.00      1.00      1.00         3
#       600000       1.00      1.00      1.00         1
#       650000       0.00      0.00      0.00         2
#       700000       0.50      1.00      0.67         2
#       750000       0.00      0.00      0.00         0
#       800000       0.50      0.50      0.50         2
#       850000       1.00      0.25      0.40         4
#      1000000       0.00      0.00      0.00         0
#      1300000       1.00      1.00      1.00         1
#      1400000       0.00      0.00      0.00         0
#      1600000       0.00      0.00      0.00         2
#      2300000       0.00      0.00      0.00         1
#      2800000       0.00      0.00      0.00         0
#      2900000       0.00      0.00      0.00         0
#      3000000       0.00      0.00      0.00         1
#      4000000       1.00      1.00      1.00         1
#
#     accuracy                           0.50        20
#    macro avg       0.38      0.36      0.35        20
# weighted avg       0.60      0.50      0.50        20
# C:\Users\mohin\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\mohin\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\mohin\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\mohin\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\mohin\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\mohin\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
from  sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score,classification_report
#initialize 
knn_classifier=KNeighborsClassifier()

knn_classifier.fit(x_train,y_train)

y_pred=knn_classifier.predict(x_test)

accuracy=accuracy_score(y_test,y_pred)
print("Accuracy",accuracy)

classification_rep=classification_report(y_test,y_pred)
print("knn classifier's classification report\n:",classification_rep)
# Out:
# Accuracy 0.05
# knn classifier's classification report
# :               precision    recall  f1-score   support
#
#       450000       0.00      0.00      0.00         0
#       500000       0.25      0.33      0.29         3
#       600000       0.00      0.00      0.00         1
#       650000       0.00      0.00      0.00         2
#       700000       0.00      0.00      0.00         2
#       750000       0.00      0.00      0.00         0
#       800000       0.00      0.00      0.00         2
#       850000       0.00      0.00      0.00         4
#      1300000       0.00      0.00      0.00         1
#      1600000       0.00      0.00      0.00         2
#      2300000       0.00      0.00      0.00         1
#      2600000       0.00      0.00      0.00         0
#      2800000       0.00      0.00      0.00         0
#      3000000       0.00      0.00      0.00         1
#      4000000       0.00      0.00      0.00         1
#
#     accuracy                           0.05        20
#    macro avg       0.02      0.02      0.02        20
# weighted avg       0.04      0.05      0.04        20
# C:\Users\mohin\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\mohin\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\mohin\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\mohin\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\mohin\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\mohin\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score

model=DecisionTreeRegressor()
model.fit(x_train,y_train)
y_preddt=model.predict(x_test)

dt_metrics={'Mean Squared Error':mean_squared_error(y_test,y_preddt),
           'Root Mean Squared Error':np.sqrt(mean_squared_error(y_test,y_preddt)),
           'Mean Absolute Error':mean_absolute_error(y_test,y_preddt),
           'R Squared':r2_score(y_test,y_preddt)}

print(dt_metrics)
# Out:
# {'Mean Squared Error': 210875000000.0, 'Root Mean Squared Error': 459211.28034925275, 'Mean Absolute Error': 232500.0, 'R Squared': 0.7421593201687351}

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score


model=LinearRegression()
model.fit(x_train, y_train)
y_pred_test=model.predict(x_test)#for evaluating test set
y_pred_train=model.predict(x_train)#for evaluating train set

#Evaluation Matrix
#now we are saving predictions
lr_metrics={'Test Mean Squared Error ':mean_squared_error(y_test,y_pred_test),
           'Test Root Mean Squared Error':np.sqrt(mean_squared_error(y_test,y_pred_test)),
           'Test Mean Absolute Error':mean_absolute_error(y_test,y_pred_test),
           'Test R Squared':r2_score(y_test,y_pred_test),
           'Train Mean Squared Error':mean_squared_error(y_train,y_pred_train),
           'Train Root Mean Squared Error':np.sqrt(mean_squared_error(y_train,y_pred_train)),
           'Train Mean Absolute Error':mean_absolute_error(y_train,y_pred_train),
           'Train R Squared':r2_score(y_train,y_pred_train)}
print(lr_metrics)
# Out:
# {'Test Mean Squared Error ': 215333015912.55756, 'Test Root Mean Squared Error': 464039.8861224728, 'Test Mean Absolute Error': 356871.4285947162, 'Test R Squared': 0.7367084234119246, 'Train Mean Squared Error': 139901629956.54993, 'Train Root Mean Squared Error': 374034.2630783307, 'Train Mean Absolute Error': 291823.2668700925, 'Train R Squared': 0.8579940189111903}

# %%
#multiple linear regression
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score


mlr=LinearRegression()
mlr.fit(x_train, y_train)
y_predmlr_test=mlr.predict(x_test)#for evaluating test set
y_predmlr_train=mlr.predict(x_train)#for evaluating train set

#Evaluation Matrix
#now we are saving predictions
mlr_metrics={'Test Mean Squared Error':mean_squared_error(y_test,y_predmlr_test),
           'Test Root Mean Squared Error':np.sqrt(mean_squared_error(y_test,y_predmlr_test)),
           'Test Mean Absolute Error':mean_absolute_error(y_test,y_predmlr_test),
           'Test R Squared':r2_score(y_test,y_predmlr_test),
           'Train Mean Squared Error':mean_squared_error(y_train,y_predmlr_train),
           'Train Root Mean Squared Error':np.sqrt(mean_squared_error(y_train,y_predmlr_train)),
           'Train Mean Absolute Error':mean_absolute_error(y_train,y_predmlr_train),
           'Train R Squared':r2_score(y_train,y_predmlr_train)}

print(mlr_metrics)
# Out:
# {'Test Mean Squared Error': 215333015912.55756, 'Test Root Mean Squared Error': 464039.8861224728, 'Test Mean Absolute Error': 356871.4285947162, 'Test R Squared': 0.7367084234119246, 'Train Mean Squared Error': 139901629956.54993, 'Train Root Mean Squared Error': 374034.2630783307, 'Train Mean Absolute Error': 291823.2668700925, 'Train R Squared': 0.8579940189111903}

# %%
from xgboost import XGBRegressor
xgb=XGBRegressor()
xgb.fit(x_train,y_train)
y_predxgb_test=xgb.predict(x_test)
y_predxgb_train=xgb.predict(x_train)
xgb_metrics={'Test Mean Squared Error':mean_squared_error(y_test,y_predxgb_test),
           'Test Root Mean Squared Error':np.sqrt(mean_squared_error(y_test,y_predxgb_test)),
           'Test Mean Absolute Error':mean_absolute_error(y_test,y_predxgb_test),
           'Test R Squared':r2_score(y_test,y_predxgb_test),
           'Train Mean Squared Error':mean_squared_error(y_train,y_predxgb_train),
           'Train Root Mean Squared Error':np.sqrt(mean_squared_error(y_train,y_predxgb_train)),
           'Train Mean Absolute Error':mean_absolute_error(y_train,y_predxgb_train),
           'Train R Squared':r2_score(y_train,y_predxgb_train)}

print(xgb_metrics)
# Out:
# {'Test Mean Squared Error': 99634150533.87094, 'Test Root Mean Squared Error': 315648.77717784833, 'Test Mean Absolute Error': 164144.6671875, 'Test R Squared': 0.8781755205308175, 'Train Mean Squared Error': 0.14976806640625, 'Train Root Mean Squared Error': 0.38699879380464486, 'Train Mean Absolute Error': 0.298828125, 'Train R Squared': 0.999999999999848}

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error,r2_score,mean_absolute_error
rf=RandomForestRegressor()
rf.fit(x_train,y_train)
y_predrf_test=rf.predict(x_test)
y_predrf_train=rf.predict(x_train)
rf_metrics={'Test Mean Squared Error':mean_squared_error(y_test,y_predrf_test),
           'Test Root Mean Squared Error':np.sqrt(mean_squared_error(y_test,y_predrf_test)),
           'Test Mean Absolute Error':mean_absolute_error(y_test,y_predrf_test),
           'Test R Squared':r2_score(y_test,y_predrf_test),
           'Train Mean Squared Error':mean_squared_error(y_train,y_predrf_train),
           'Train Root Mean Squared Error':np.sqrt(mean_squared_error(y_train,y_predrf_train)),
           'Train Mean Absolute Error':mean_absolute_error(y_train,y_predrf_train),
           'Train R Squared':r2_score(y_train,y_predrf_train)}

print(rf_metrics)
# Out:
# {'Test Mean Squared Error': 133543037500.0, 'Test Root Mean Squared Error': 365435.40810928546, 'Test Mean Absolute Error': 201375.0, 'Test R Squared': 0.8367145106070796, 'Train Mean Squared Error': 7308515625.0, 'Train Root Mean Squared Error': 85489.85685448303, 'Train Mean Absolute Error': 55593.75, 'Train R Squared': 0.9925815522524408}

# %%
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score

gb=GradientBoostingRegressor()
gb.fit(x_train,y_train)
y_predgb_test=gb.predict(x_test)
y_predgb_train=gb.predict(x_train)
gb_metrics={'Test Mean Squared Error':mean_squared_error(y_test,y_predgb_test),
           'Test Root Mean Squared Error':np.sqrt(mean_squared_error(y_test,y_predgb_test)),
           'Test Mean Absolute Error':mean_absolute_error(y_test,y_predgb_test),
           'Test R Squared':r2_score(y_test,y_predgb_test),
           'Train Mean Squared Error':mean_squared_error(y_train,y_predgb_train),
           'Train Root Mean Squared Error':np.sqrt(mean_squared_error(y_train,y_predgb_train)),
           'Train Mean Absolute Error':mean_absolute_error(y_train,y_predgb_train),
           'Train R Squared':r2_score(y_train,y_predgb_train)}
gb_metrics
# Out:
# {'Test Mean Squared Error': 114113597367.5778,
#  'Test Root Mean Squared Error': 337807.0416192916,
#  'Test Mean Absolute Error': 161307.23185409562,
#  'Test R Squared': 0.8604712387753527,
#  'Train Mean Squared Error': 158272093.4364725,
#  'Train Root Mean Squared Error': 12580.623730025174,
#  'Train Mean Absolute Error': 9449.989288681103,
#  'Train R Squared': 0.9998393472333782}

# %%
import shap
# create shap explainer for trained the model
explainer=shap.Explainer(model,x_train)
shap_values=explainer(x_test)  # shap_values for test data
#summary plot
shap.summary_plot(shap_values,x_test)

# %% [markdown]
# **Hyper-parameter Tunning**

# %% [markdown]
# **GridSearch**

# %%
from sklearn.model_selection import GridSearchCV
from xgboost import XGBRegressor

#initializing the XGBoost model
xgb_model=XGBRegressor(random_state=42)

#defining the parameter grid
param_grid={
    'learning_rate':[0.01,0.05,0.1],
    'max_depth':[3,5,7],
    'n_extimators':[100,200,300],
    'subsample':[0.8,0.9,1.0],
    'min_chile_weight':[1,3,5]
}

#performing GridSearchCV

grid_search=GridSearchCV(
    estimator=xgb_model,
    param_grid=param_grid,
    cv=3, #3-fold cross-validation
    scoring='neg_mean_squared_error', #evvaluation metric
    verbose=2,
    n_jobs=-1
)

#fitting GridSearchCV
grid_search.fit(x_train,y_train)


#displaying the best parameters
print("Best parameters:",grid_search.best_params_)
# Out:
# Fitting 3 folds for each of 243 candidates, totalling 729 fits
# Best parameters: {'learning_rate': 0.05, 'max_depth': 3, 'min_chile_weight': 1, 'n_extimators': 100, 'subsample': 0.8}
# C:\Users\mohin\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [16:26:56] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "min_chile_weight", "n_extimators" } are not used.
#
#   warnings.warn(smsg, UserWarning)

# %% [markdown]
# **RandomSearch**

# %%
from sklearn.model_selection import RandomizedSearchCV
import numpy as np

#Defining the parameter distribution
param_dist={
    'learning_rate':np.linspace(0.01,0.2,10),
    'max_depth':[3,5,7,9],
    'n_estimators':[100,200,300,500],
    'subsample':np.linspace(0.7,1.0,4),
    'colsample_bytree':np.linspace(0.7,1.0,4),
    'min_child_weight':[1,3,5,7]
}

#remaining RandomizedSearchCV

random_search=RandomizedSearchCV(
    estimator=xgb_model,
    param_distributions=param_dist,
    n_iter=50, #number of parameter combinations to try
    cv=3, #3-fold cross-validation
    scoring='neg_mean_squared_error',
    verbose=2,
    random_state=42,
    n_jobs=-1
)

#fitting RandomizedSearchCV
random_search.fit(x_train,y_train)

#displaying the best parameters
print("Best parameters:",random_search.best_params_)
# Out:
# Fitting 3 folds for each of 50 candidates, totalling 150 fits
# Best parameters: {'subsample': 0.9, 'n_estimators': 200, 'min_child_weight': 5, 'max_depth': 5, 'learning_rate': 0.052222222222222225, 'colsample_bytree': 0.9}

# %%
import pickle
with open("Car price project.pkl", "wb") as f:
    pickle.dump(model, f)
